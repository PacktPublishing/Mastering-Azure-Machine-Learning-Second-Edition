# %%
from utils import *

# %%
from azureml.core import Workspace, Experiment
ws = Workspace.from_config()
exp = Experiment(workspace=ws, name='access_dataset')
# Out:
# Warning: Falling back to use azure cli login credentials.
# If you run your code in unattended mode, i.e., where you can't give a user input, then we recommend to use ServicePrincipalAuthentication or MsiAuthentication.
# Please refer to aka.ms/aml-notebook-auth for different authentication mechanisms in azureml-sdk.

# %%
from azureml.core import Dataset

path ='https://dprepdata.blob.core.windows.net/demo/Titanic.csv'

# Create a direct dataset
ds = Dataset.Tabular.from_delimited_files(path)
ds

# %%
# Register the dataset
ds = ds.register(workspace=ws, name="titanic")
ds
# Out:
# {
#   "source": [
#     "https://dprepdata.blob.core.windows.net/demo/Titanic.csv"
#   ],
#   "definition": [
#     "GetFiles",
#     "ParseDelimited",
#     "DropColumns",
#     "SetColumnTypes"
#   ],
#   "registration": {
#     "id": "4e3294cb-3975-4850-bfc6-51dc981b9548",
#     "name": "titanic",
#     "version": 1,
#     "workspace": "Workspace.create(name='mldemows', subscription_id='21dc412b-d9eb-42e7-8317-55bc8eb10cf5', resource_group='packt')"
#   }
# }

# %%
# list all datasets from a workspace
datasets = Dataset.get_all(ws)
datasets

# %%
# Now we can retrieve the dataset by name (and version)
ds = Dataset.get_by_name(ws, "titanic")
ds
# Out:
# {
#   "source": [
#     "https://dprepdata.blob.core.windows.net/demo/Titanic.csv"
#   ],
#   "definition": [
#     "GetFiles",
#     "ParseDelimited",
#     "DropColumns",
#     "SetColumnTypes"
#   ],
#   "registration": {
#     "id": "4e3294cb-3975-4850-bfc6-51dc981b9548",
#     "name": "titanic",
#     "version": 1,
#     "workspace": "Workspace.create(name='mldemows', subscription_id='21dc412b-d9eb-42e7-8317-55bc8eb10cf5', resource_group='packt')"
#   }
# }

# %%
ds.to_pandas_dataframe()
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500  None        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250  None        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500  None        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000  None        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500  None        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500  None        Q
#
# [891 rows x 12 columns]

# %%
from azureml.core import ScriptRunConfig

src = ScriptRunConfig(source_directory="code",
                      script='access_data_from_dataset.py',
                      arguments=['--input', ds.as_named_input('titanic')],
                      environment=get_current_env())

# Submit the run configuration for your training run
run = exp.submit(src)
run.wait_for_completion(show_output=True)
# Out:
# RunId: access_dataset_1630144272_74a5b2c5
# Web View: https://ml.azure.com/runs/access_dataset_1630144272_74a5b2c5?wsid=/subscriptions/21dc412b-d9eb-42e7-8317-55bc8eb10cf5/resourcegroups/packt/workspaces/mldemows&tid=e702ab66-1ac1-42ba-b41b-8195d943a1e0
#
# Streaming azureml-logs/60_control_log.txt
# =========================================
#
# [2021-08-28T09:51:15.518540] Using urllib.request Python 3.0 or later
# Streaming log file azureml-logs/60_control_log.txt
# Running: ['/bin/bash', '/private/var/folders/dq/w2q25sxj32l_4y56t759w42r0000gn/T/azureml_runs/access_dataset_1630144272_74a5b2c5/azureml-environment-setup/conda_env_checker.sh']
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
#
# [2021-08-28T09:51:16.463597] Entering context manager injector.
# [2021-08-28T09:51:17.434259] context_manager_injector.py Command line Options: Namespace(inject=['ProjectPythonPath:context_managers.ProjectPythonPath', 'RunHistory:context_managers.RunHistory', 'TrackUserError:context_managers.TrackUserError'], invocation=['access_dataset.py', '--input-data', '4e3294cb-3975-4850-bfc6-51dc981b9548'])
# Script type = None
# [2021-08-28T09:51:17.439920] Entering Run History Context Manager.
# [2021-08-28T09:51:18.380533] Current directory: /private/var/folders/dq/w2q25sxj32l_4y56t759w42r0000gn/T/azureml_runs/access_dataset_1630144272_74a5b2c5
# [2021-08-28T09:51:18.380877] Preparing to call script [access_dataset.py] with arguments:['--input-data', '4e3294cb-3975-4850-bfc6-51dc981b9548']
# [2021-08-28T09:51:18.380995] After variable expansion, calling script [access_dataset.py] with arguments:['--input-data', '4e3294cb-3975-4850-bfc6-51dc981b9548']
#
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500  None         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250  None         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500  None         S
#
# [5 rows x 12 columns]
#
#
# [2021-08-28T09:51:25.737068] The experiment completed successfully. Finalizing run...
# [2021-08-28T09:51:25.737120] Start FinalizingInRunHistory
# [2021-08-28T09:51:25.745921] Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 8639
# Cleaning up all outstanding Run operations, waiting 300.0 seconds
# 2 items cleaning up...
# Cleanup took 0.3869640827178955 seconds
# [2021-08-28T09:51:27.948631] Finished context manager injector.
#
# Execution Summary
# =================
# RunId: access_dataset_1630144272_74a5b2c5
# Web View: https://ml.azure.com/runs/access_dataset_1630144272_74a5b2c5?wsid=/subscriptions/21dc412b-d9eb-42e7-8317-55bc8eb10cf5/resourcegroups/packt/workspaces/mldemows&tid=e702ab66-1ac1-42ba-b41b-8195d943a1e0
# {'runId': 'access_dataset_1630144272_74a5b2c5',
#  'target': 'local',
#  'status': 'Completed',
#  'startTimeUtc': '2021-08-28T09:51:15.627738Z',
#  'endTimeUtc': '2021-08-28T09:52:34.769448Z',
#  'properties': {'_azureml.ComputeTargetType': 'local',
#   'ContentSnapshotId': '5b19fd92-8e43-4be8-a3f7-aec1058af545'},
#  'inputDatasets': [{'dataset': {'id': '4e3294cb-3975-4850-bfc6-51dc981b9548'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'titanic', 'mechanism': 'Direct'}}, {'dataset': {'id': '4e3294cb-3975-4850-bfc6-51dc981b9548'}, 'consumptionDetails': {'type': 'Reference'}}],
#  'outputDatasets': [],
#  'runDefinition': {'script': 'access_dataset.py',
#   'command': '',
#   'useAbsolutePath': False,
#   'arguments': ['--input-data', 'DatasetConsumptionConfig:titanic'],
#   'sourceDirectoryDataStore': None,
#   'framework': 'Python',
#   'communicator': 'None',
#   'target': 'local',
#   'dataReferences': {},
#   'data': {'titanic': {'dataLocation': {'dataset': {'id': '4e3294cb-3975-4850-bfc6-51dc981b9548',
#       'name': 'titanic',
#       'version': '1'},
#      'dataPath': None,
#      'uri': None},
#     'mechanism': 'Direct',
#     'environmentVariableName': 'titanic',
#     'pathOnCompute': None,
#     'overwrite': False,
#     'options': None}},
#   'outputData': {},
#   'datacaches': [],
#   'jobName': None,
#   'maxRunDurationSeconds': 2592000,
#   'nodeCount': 1,
#   'priority': None,
#   'credentialPassthrough': False,
#   'identity': None,
#   'environment': {'name': 'user-managed-env',
#    'version': 'Autosave_2021-08-28T09:12:57Z_e37cfa94',
#    'python': {'interpreterPath': 'python',
#     'userManagedDependencies': True,
#     'condaDependencies': {'channels': ['anaconda', 'conda-forge'],
#      'dependencies': ['python=3.6.2', {'pip': ['azureml-defaults']}],
#      'name': 'project_environment'},
#     'baseCondaEnvironment': None},
#    'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'},
#    'docker': {'baseImage': 'mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210714.v1',
#     'platform': {'os': 'Linux', 'architecture': 'amd64'},
#     'baseDockerfile': None,
#     'baseImageRegistry': {'address': None, 'username': None, 'password': None},
#     'enabled': False,
#     'arguments': []},
#    'spark': {'repositories': [], 'packages': [], 'precachePackages': True},
#    'inferencingStackVersion': None},
#   'history': {'outputCollection': True,
#    'directoriesToWatch': ['logs'],
#    'enableMLflowTracking': True,
#    'snapshotProject': True},
#   'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment',
#     'spark.yarn.maxAppAttempts': '1'}},
#   'parallelTask': {'maxRetriesPerWorker': 0,
#    'workerCountPerNode': 1,
#    'terminalExitCodes': None,
#    'configuration': {}},
#   'amlCompute': {'name': None,
#    'vmSize': None,
#    'retainCluster': False,
#    'clusterMaxNodeCount': None},
#   'aiSuperComputer': {'instanceType': 'D2',
#    'imageVersion': 'pytorch-1.7.0',
#    'location': None,
#    'aiSuperComputerStorageData': None,
#    'interactive': False,
#    'scalePolicy': None,
#    'virtualClusterArmId': None,
#    'tensorboardLogDirectory': None,
#    'sshPublicKey': None,
#    'enableAzmlInt': True,
#    'priority': 'Medium',
#    'slaTier': 'Standard',
#    'userAlias': None},
#   'kubernetesCompute': {'instanceType': None},
#   'tensorflow': {'workerCount': 1, 'parameterServerCount': 1},
#   'mpi': {'processCountPerNode': 1},
#   'pyTorch': {'communicationBackend': 'nccl', 'processCount': None},
#   'hdi': {'yarnDeployMode': 'Cluster'},
#   'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5},
#   'exposedPorts': None,
#   'docker': {'useDocker': False,
#    'sharedVolumes': True,
#    'shmSize': '2g',
#    'arguments': []},
#   'cmk8sCompute': {'configuration': {}},
#   'commandReturnCodeConfig': {'returnCode': 'Zero',
#    'successfulReturnCodes': []},
#   'environmentVariables': {},
#   'applicationEndpoints': {},
#   'parameters': [],
#   'dataBricks': {'workers': 0,
#    'minimumWorkerCount': 0,
#    'maxMumWorkerCount': 0,
#    'sparkVersion': '4.0.x-scala2.11',
#    'nodeTypeId': 'Standard_D3_v2',
#    'sparkConf': {},
#    'sparkEnvVars': {},
#    'instancePoolId': None,
#    'timeoutSeconds': 0,
#    'jarLibraries': [],
#    'eggLibraries': [],
#    'whlLibraries': [],
#    'pypiLibraries': [],
#    'rCranLibraries': [],
#    'mavenLibraries': []}},
#  'logFiles': {'azureml-logs/60_control_log.txt': 'https://mldemows8396108817.blob.core.windows.net/azureml/ExperimentRun/dcid.access_dataset_1630144272_74a5b2c5/azureml-logs/60_control_log.txt?sv=2019-07-07&sr=b&sig=S4QYaTZcaM%2FE%2FNz9MCVsMCq%2F2Q71q9BTy%2F1MqaDAhNg%3D&st=2021-08-28T09%3A42%3A41Z&se=2021-08-28T17%3A52%3A41Z&sp=r',
#   'azureml-logs/70_driver_log.txt': 'https://mldemows8396108817.blob.core.windows.net/azureml/ExperimentRun/dcid.access_dataset_1630144272_74a5b2c5/azureml-logs/70_driver_log.txt?sv=2019-07-07&sr=b&sig=JP4L41GzXjUl94galbE3ExynoO3dTBvOY4ohPMKaPZ4%3D&st=2021-08-28T09%3A42%3A41Z&se=2021-08-28T17%3A52%3A41Z&sp=r',
#   'logs/azureml/8639_azureml.log': 'https://mldemows8396108817.blob.core.windows.net/azureml/ExperimentRun/dcid.access_dataset_1630144272_74a5b2c5/logs/azureml/8639_azureml.log?sv=2019-07-07&sr=b&sig=IemXuUWuGDSF%2F6f713Fy2thiB%2FwYAywZV97FNVcfdlQ%3D&st=2021-08-28T09%3A41%3A27Z&se=2021-08-28T17%3A51%3A27Z&sp=r',
#   'logs/azureml/dataprep/backgroundProcess.log': 'https://mldemows8396108817.blob.core.windows.net/azureml/ExperimentRun/dcid.access_dataset_1630144272_74a5b2c5/logs/azureml/dataprep/backgroundProcess.log?sv=2019-07-07&sr=b&sig=63Oedu4j7xjxODIDNzCpnMdDRKa9E60y4MbDUnVj%2BNk%3D&st=2021-08-28T09%3A41%3A27Z&se=2021-08-28T17%3A51%3A27Z&sp=r',
#   'logs/azureml/dataprep/backgroundProcess_Telemetry.log': 'https://mldemows8396108817.blob.core.windows.net/azureml/ExperimentRun/dcid.access_dataset_1630144272_74a5b2c5/logs/azureml/dataprep/backgroundProcess_Telemetry.log?sv=2019-07-07&sr=b&sig=3JekkzJnafiu6uKAS1J4urOxTAXkHiz2YrwnvU1f66w%3D&st=2021-08-28T09%3A41%3A27Z&se=2021-08-28T17%3A51%3A27Z&sp=r'},
#  'submittedBy': 'Christoph Körner'}
