# %%
from utils import *

# %%
from azureml.core import Workspace, Experiment

ws = Workspace.from_config()
exp = Experiment(workspace=ws, name='access_dataset_as_download')

# %%
from azureml.core import Dataset

dataset = Dataset.get_by_name(ws, "cifar10")
dataset
# Out:
# {
#   "source": [
#     "('mldata', 'cifar10/')"
#   ],
#   "definition": [
#     "GetDatastoreFiles"
#   ],
#   "registration": {
#     "id": "0217c2d7-057e-486a-a133-5b0e0f15716a",
#     "name": "cifar10",
#     "version": 1,
#     "workspace": "Workspace.create(name='mldemows', subscription_id='21dc412b-d9eb-42e7-8317-55bc8eb10cf5', resource_group='packt')"
#   }
# }

# %%
folder = '/tmp/cifar10-data'
path = dataset.download(folder)
path
# Out:
# ['/tmp/cifar10-data/batches.meta',
#  '/tmp/cifar10-data/data_batch_1',
#  '/tmp/cifar10-data/data_batch_2',
#  '/tmp/cifar10-data/data_batch_3',
#  '/tmp/cifar10-data/data_batch_4',
#  '/tmp/cifar10-data/data_batch_5',
#  '/tmp/cifar10-data/readme.html',
#  '/tmp/cifar10-data/test_batch']

# %%
from azureml.core import ScriptRunConfig

src = ScriptRunConfig(source_directory="code",
                      script='access_dataset.py',
                      arguments=['--input', dataset.as_named_input('cifar10').as_download()],
                      environment=get_current_env())

# Submit the run configuration for your training run
run = exp.submit(src)
run.wait_for_completion(show_output=True)
# Out:
# RunId: access_dataset_as_download_1630266194_6a2a4d78
# Web View: https://ml.azure.com/runs/access_dataset_as_download_1630266194_6a2a4d78?wsid=/subscriptions/21dc412b-d9eb-42e7-8317-55bc8eb10cf5/resourcegroups/packt/workspaces/mldemows&tid=e702ab66-1ac1-42ba-b41b-8195d943a1e0
#
# Streaming azureml-logs/60_control_log.txt
# =========================================
#
# [2021-08-29T19:43:16.999481] Using urllib.request Python 3.0 or later
# Streaming log file azureml-logs/60_control_log.txt
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
#
# [2021-08-29T19:43:18.063732] Entering context manager injector.
# [2021-08-29T19:43:18.792376] context_manager_injector.py Command line Options: Namespace(inject=['ProjectPythonPath:context_managers.ProjectPythonPath', 'Dataset:context_managers.Datasets', 'RunHistory:context_managers.RunHistory', 'TrackUserError:context_managers.TrackUserError'], invocation=['access_dataset_as_download.py', '--input', 'DatasetConsumptionConfig:cifar10'])
# [2021-08-29T19:43:18.876] Initialize DatasetContextManager.
# Script type = None
# Set Dataset cifar10's target path to /var/folders/dq/w2q25sxj32l_4y56t759w42r0000gn/T/cifar10_0217c2d7-057e-486a-a133-5b0e0f15716a
# [2021-08-29T19:43:19.043] Enter __enter__ of DatasetContextManager
# [2021-08-29T19:43:19.044] SDK version: azureml-core==1.33.0.post1 azureml-dataprep==2.20.1. Session id: 68fbc3e4-67c1-4ed4-ac59-6af76f80275a. Run id: access_dataset_as_download_1630266194_6a2a4d78.
# [2021-08-29T19:43:19.044] Processing 'cifar10'.
# [2021-08-29T19:43:19.057] Mode: 'download'.
# [2021-08-29T19:43:19.064] Path on compute is specified: 'False'.
# [2021-08-29T19:43:21.850] Processing dataset FileDataset
# {
#   "source": [
#     "('mldata', 'cifar10/')"
#   ],
#   "definition": [
#     "GetDatastoreFiles"
#   ],
#   "registration": {
#     "id": "0217c2d7-057e-486a-a133-5b0e0f15716a",
#     "name": "cifar10",
#     "version": 1,
#     "workspace": "Workspace.create(name='mldemows', subscription_id='21dc412b-d9eb-42e7-8317-55bc8eb10cf5', resource_group='packt')"
#   }
# }
# [2021-08-29T19:43:21.850] Downloading cifar10 to /var/folders/dq/w2q25sxj32l_4y56t759w42r0000gn/T/cifar10_0217c2d7-057e-486a-a133-5b0e0f15716a
# [2021-08-29T19:43:33.877] Downloaded cifar10 to /var/folders/dq/w2q25sxj32l_4y56t759w42r0000gn/T/cifar10_0217c2d7-057e-486a-a133-5b0e0f15716a as folder.
# [2021-08-29T19:43:33.897] Exit __enter__ of DatasetContextManager
# [2021-08-29T19:43:33.898098] Entering Run History Context Manager.
# [2021-08-29T19:43:34.138233] Current directory: /private/var/folders/dq/w2q25sxj32l_4y56t759w42r0000gn/T/azureml_runs/access_dataset_as_download_1630266194_6a2a4d78
# [2021-08-29T19:43:34.138771] Preparing to call script [access_dataset_as_download.py] with arguments:['--input', '$cifar10']
# [2021-08-29T19:43:34.138824] After variable expansion, calling script [access_dataset_as_download.py] with arguments:['--input', '/var/folders/dq/w2q25sxj32l_4y56t759w42r0000gn/T/cifar10_0217c2d7-057e-486a-a133-5b0e0f15716a']
#
# Dataset downloaded to: /var/folders/dq/w2q25sxj32l_4y56t759w42r0000gn/T/cifar10_0217c2d7-057e-486a-a133-5b0e0f15716a
# ['data_batch_1', 'readme.html', 'batches.meta', 'data_batch_2', 'data_batch_5', 'test_batch', 'data_batch_4', 'data_batch_3']
#
#
# [2021-08-29T19:43:34.164799] The experiment completed successfully. Finalizing run...
# [2021-08-29T19:43:34.164824] Start FinalizingInRunHistory
# [2021-08-29T19:43:34.166281] Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 18006
# Cleaning up all outstanding Run operations, waiting 300.0 seconds
# 2 items cleaning up...
# Cleanup took 0.4208948612213135 seconds
# [2021-08-29T19:43:36.358] Enter __exit__ of DatasetContextManager
# [2021-08-29T19:43:36.358] Exit __exit__ of DatasetContextManager
# [2021-08-29T19:43:36.358897] Finished context manager injector.
#
# Execution Summary
# =================
# RunId: access_dataset_as_download_1630266194_6a2a4d78
# Web View: https://ml.azure.com/runs/access_dataset_as_download_1630266194_6a2a4d78?wsid=/subscriptions/21dc412b-d9eb-42e7-8317-55bc8eb10cf5/resourcegroups/packt/workspaces/mldemows&tid=e702ab66-1ac1-42ba-b41b-8195d943a1e0
# {'runId': 'access_dataset_as_download_1630266194_6a2a4d78',
#  'target': 'local',
#  'status': 'Completed',
#  'startTimeUtc': '2021-08-29T19:43:17.108686Z',
#  'endTimeUtc': '2021-08-29T19:44:44.161966Z',
#  'properties': {'_azureml.ComputeTargetType': 'local',
#   'ContentSnapshotId': '44c97c30-bcf7-453d-94f4-5e15aae782d9'},
#  'inputDatasets': [{'dataset': {'id': '0217c2d7-057e-486a-a133-5b0e0f15716a'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'cifar10', 'mechanism': 'Download'}}],
#  'outputDatasets': [],
#  'runDefinition': {'script': 'access_dataset_as_download.py',
#   'command': '',
#   'useAbsolutePath': False,
#   'arguments': ['--input', 'DatasetConsumptionConfig:cifar10'],
#   'sourceDirectoryDataStore': None,
#   'framework': 'Python',
#   'communicator': 'None',
#   'target': 'local',
#   'dataReferences': {},
#   'data': {'cifar10': {'dataLocation': {'dataset': {'id': '0217c2d7-057e-486a-a133-5b0e0f15716a',
#       'name': 'cifar10',
#       'version': '1'},
#      'dataPath': None,
#      'uri': None},
#     'mechanism': 'Download',
#     'environmentVariableName': 'cifar10',
#     'pathOnCompute': None,
#     'overwrite': False,
#     'options': None}},
#   'outputData': {},
#   'datacaches': [],
#   'jobName': None,
#   'maxRunDurationSeconds': 2592000,
#   'nodeCount': 1,
#   'priority': None,
#   'credentialPassthrough': False,
#   'identity': None,
#   'environment': {'name': 'user-managed-env',
#    'version': 'Autosave_2021-08-28T09:12:57Z_e37cfa94',
#    'python': {'interpreterPath': 'python',
#     'userManagedDependencies': True,
#     'condaDependencies': {'channels': ['anaconda', 'conda-forge'],
#      'dependencies': ['python=3.6.2', {'pip': ['azureml-defaults']}],
#      'name': 'project_environment'},
#     'baseCondaEnvironment': None},
#    'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'},
#    'docker': {'baseImage': 'mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210714.v1',
#     'platform': {'os': 'Linux', 'architecture': 'amd64'},
#     'baseDockerfile': None,
#     'baseImageRegistry': {'address': None, 'username': None, 'password': None},
#     'enabled': False,
#     'arguments': []},
#    'spark': {'repositories': [], 'packages': [], 'precachePackages': True},
#    'inferencingStackVersion': None},
#   'history': {'outputCollection': True,
#    'directoriesToWatch': ['logs'],
#    'enableMLflowTracking': True,
#    'snapshotProject': True},
#   'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment',
#     'spark.yarn.maxAppAttempts': '1'}},
#   'parallelTask': {'maxRetriesPerWorker': 0,
#    'workerCountPerNode': 1,
#    'terminalExitCodes': None,
#    'configuration': {}},
#   'amlCompute': {'name': None,
#    'vmSize': None,
#    'retainCluster': False,
#    'clusterMaxNodeCount': None},
#   'aiSuperComputer': {'instanceType': 'D2',
#    'imageVersion': 'pytorch-1.7.0',
#    'location': None,
#    'aiSuperComputerStorageData': None,
#    'interactive': False,
#    'scalePolicy': None,
#    'virtualClusterArmId': None,
#    'tensorboardLogDirectory': None,
#    'sshPublicKey': None,
#    'enableAzmlInt': True,
#    'priority': 'Medium',
#    'slaTier': 'Standard',
#    'userAlias': None},
#   'kubernetesCompute': {'instanceType': None},
#   'tensorflow': {'workerCount': 1, 'parameterServerCount': 1},
#   'mpi': {'processCountPerNode': 1},
#   'pyTorch': {'communicationBackend': 'nccl', 'processCount': None},
#   'hdi': {'yarnDeployMode': 'Cluster'},
#   'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5},
#   'exposedPorts': None,
#   'docker': {'useDocker': False,
#    'sharedVolumes': True,
#    'shmSize': '2g',
#    'arguments': []},
#   'cmk8sCompute': {'configuration': {}},
#   'commandReturnCodeConfig': {'returnCode': 'Zero',
#    'successfulReturnCodes': []},
#   'environmentVariables': {},
#   'applicationEndpoints': {},
#   'parameters': [],
#   'dataBricks': {'workers': 0,
#    'minimumWorkerCount': 0,
#    'maxMumWorkerCount': 0,
#    'sparkVersion': '4.0.x-scala2.11',
#    'nodeTypeId': 'Standard_D3_v2',
#    'sparkConf': {},
#    'sparkEnvVars': {},
#    'instancePoolId': None,
#    'timeoutSeconds': 0,
#    'jarLibraries': [],
#    'eggLibraries': [],
#    'whlLibraries': [],
#    'pypiLibraries': [],
#    'rCranLibraries': [],
#    'mavenLibraries': []}},
#  'logFiles': {'azureml-logs/60_control_log.txt': 'https://mldemows8396108817.blob.core.windows.net/azureml/ExperimentRun/dcid.access_dataset_as_download_1630266194_6a2a4d78/azureml-logs/60_control_log.txt?sv=2019-07-07&sr=b&sig=RZ%2FYqQyepB7JQcLcfHFHgQySlUofP8I6YCbhZeG0lKM%3D&st=2021-08-29T19%3A34%3A48Z&se=2021-08-30T03%3A44%3A48Z&sp=r',
#   'azureml-logs/70_driver_log.txt': 'https://mldemows8396108817.blob.core.windows.net/azureml/ExperimentRun/dcid.access_dataset_as_download_1630266194_6a2a4d78/azureml-logs/70_driver_log.txt?sv=2019-07-07&sr=b&sig=2M1iAuJ12F0vxdrv4Iwir94fysKynyV97eq%2FZOP9Pqs%3D&st=2021-08-29T19%3A34%3A49Z&se=2021-08-30T03%3A44%3A49Z&sp=r',
#   'logs/azureml/18006_azureml.log': 'https://mldemows8396108817.blob.core.windows.net/azureml/ExperimentRun/dcid.access_dataset_as_download_1630266194_6a2a4d78/logs/azureml/18006_azureml.log?sv=2019-07-07&sr=b&sig=wy1%2FrexzPcrsQYhgMxZ1VvCeVaZYcwpjm%2BJus9YQDe8%3D&st=2021-08-29T19%3A33%3A34Z&se=2021-08-30T03%3A43%3A34Z&sp=r',
#   'logs/azureml/dataprep/backgroundProcess.log': 'https://mldemows8396108817.blob.core.windows.net/azureml/ExperimentRun/dcid.access_dataset_as_download_1630266194_6a2a4d78/logs/azureml/dataprep/backgroundProcess.log?sv=2019-07-07&sr=b&sig=Y%2B9TUhdMPL%2BdECwhgtOM8jLSNX8W54Ri3QP73I34yYQ%3D&st=2021-08-29T19%3A33%3A34Z&se=2021-08-30T03%3A43%3A34Z&sp=r',
#   'logs/azureml/dataprep/backgroundProcess_Telemetry.log': 'https://mldemows8396108817.blob.core.windows.net/azureml/ExperimentRun/dcid.access_dataset_as_download_1630266194_6a2a4d78/logs/azureml/dataprep/backgroundProcess_Telemetry.log?sv=2019-07-07&sr=b&sig=HJ9qP1y0FpHDerplXev13xlmCFBnC%2F7APk%2F3zYM1fa4%3D&st=2021-08-29T19%3A33%3A34Z&se=2021-08-30T03%3A43%3A34Z&sp=r'},
#  'submittedBy': 'Christoph Körner'}
