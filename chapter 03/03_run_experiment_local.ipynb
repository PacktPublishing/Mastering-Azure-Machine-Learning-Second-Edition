# %%
from azureml.core import Workspace, Experiment

# Configure experiment
ws = Workspace.from_config()
exp = Experiment(workspace=ws, name='cifar10_cnn_remote')

# %%
import os
# define the execution script location
script = 'cifar10_cnn_remote.py'
script_folder = os.path.join(os.getcwd(), 'code')

# %%
from azureml.core.environment import Environment
# set a local environment by defining that we handle all dependencies
myenv = Environment(name = "user-managed-env")
myenv.python.user_managed_dependencies = True
# show environment object
myenv
# Out:
# {
#     "databricks": {
#         "eggLibraries": [],
#         "jarLibraries": [],
#         "mavenLibraries": [],
#         "pypiLibraries": [],
#         "rcranLibraries": []
#     },
#     "docker": {
#         "arguments": [],
#         "baseDockerfile": null,
#         "baseImage": "mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210714.v1",
#         "baseImageRegistry": {
#             "address": null,
#             "password": null,
#             "registryIdentity": null,
#             "username": null
#         },
#         "enabled": false,
#         "platform": {
#             "architecture": "amd64",
#             "os": "Linux"
#         },
#         "sharedVolumes": true,
#         "shmSize": "2g"
#     },
#     "environmentVariables": {
#         "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#     },
#     "inferencingStackVersion": null,
#     "name": "user-managed-env",
#     "python": {
#         "baseCondaEnvironment": null,
#         "condaDependencies": {
#             "channels": [
#                 "anaconda",
#                 "conda-forge"
#             ],
#             "dependencies": [
#                 "python=3.6.2",
#                 {
#                     "pip": [
#                         "azureml-defaults"
#                     ]
#                 }
#             ],
#             "name": "project_environment"
#         },
#         "condaDependenciesFile": null,
#         "interpreterPath": "python",
#         "userManagedDependencies": true
#     },
#     "r": null,
#     "spark": {
#         "packages": [],
#         "precachePackages": true,
#         "repositories": []
#     },
#     "version": null
# }

# %%
from azureml.core import ScriptRunConfig

runconfig = ScriptRunConfig(source_directory=script_folder,
                      script=script,
                      environment = myenv)
run = exp.submit(runconfig)
run.wait_for_completion(show_output=True)
# Out:
# RunId: cifar10_cnn_remote_1629732321_e5e480bb
# Web View: https://ml.azure.com/runs/cifar10_cnn_remote_1629732321_e5e480bb?wsid=/subscriptions/972e63cb-550d-4c1e-8dae-59241b6336ca/resourcegroups/mldemo/workspaces/mldemows&tid=c643d8c8-4abb-47ba-808c-bf73f60161f1
#
# Streaming azureml-logs/60_control_log.txt
# =========================================
#
# [2021-08-23T15:25:24.927695] Entering context manager injector.
# [2021-08-23T15:25:29.236167] Using urllib.request Python 3.0 or later
# Streaming log file azureml-logs/60_control_log.txt
# Running: ['cmd.exe', '/c', 'C:\\Users\\Arcticus\\AppData\\Local\\Temp\\azureml_runs\\cifar10_cnn_remote_1629732321_e5e480bb\\azureml-environment-setup/conda_env_checker.bat']
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
#
# [2021-08-23T15:25:31.533022] Entering context manager injector.
# [2021-08-23T15:25:36.068885] context_manager_injector.py Command line Options: Namespace(inject=['ProjectPythonPath:context_managers.ProjectPythonPath', 'RunHistory:context_managers.RunHistory', 'TrackUserError:context_managers.TrackUserError'], invocation=['cifar10_cnn_remote.py'])
# Script type = None
# [2021-08-23T15:25:36.075867] Entering Run History Context Manager.
# [2021-08-23T15:25:40.786263] Current directory: C:\Users\Arcticus\AppData\Local\Temp\azureml_runs\cifar10_cnn_remote_1629732321_e5e480bb
# [2021-08-23T15:25:40.786263] Preparing to call script [cifar10_cnn_remote.py] with arguments:[]
# [2021-08-23T15:25:40.786263] After variable expansion, calling script [cifar10_cnn_remote.py] with arguments:[]
#
# 2021-08-23 16:25:40.907749: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 
Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 60076
# Cleaning up all outstanding Run operations, waiting 300.0 seconds
# 3 items cleaning up...
# Cleanup took 2.0325610637664795 seconds
# [2021-08-23T15:34:03.715599] Finished context manager injector.
#
# Execution Summary
# =================
# RunId: cifar10_cnn_remote_1629732321_e5e480bb
# Web View: https://ml.azure.com/runs/cifar10_cnn_remote_1629732321_e5e480bb?wsid=/subscriptions/972e63cb-550d-4c1e-8dae-59241b6336ca/resourcegroups/mldemo/workspaces/mldemows&tid=c643d8c8-4abb-47ba-808c-bf73f60161f1
# {'runId': 'cifar10_cnn_remote_1629732321_e5e480bb',
#  'target': 'local',
#  'status': 'Completed',
#  'startTimeUtc': '2021-08-23T15:25:29.797666Z',
#  'endTimeUtc': '2021-08-23T15:34:30.561768Z',
#  'properties': {'_azureml.ComputeTargetType': 'local',
#   'ContentSnapshotId': 'f93f203f-7c6d-4338-ab65-c5845495b8d8'},
#  'inputDatasets': [],
#  'outputDatasets': [],
#  'runDefinition': {'script': 'cifar10_cnn_remote.py',
#   'command': '',
#   'useAbsolutePath': False,
#   'arguments': [],
#   'sourceDirectoryDataStore': None,
#   'framework': 'Python',
#   'communicator': 'None',
#   'target': 'local',
#   'dataReferences': {},
#   'data': {},
#   'outputData': {},
#   'datacaches': [],
#   'jobName': None,
#   'maxRunDurationSeconds': 2592000,
#   'nodeCount': 1,
#   'priority': None,
#   'credentialPassthrough': False,
#   'identity': None,
#   'environment': {'name': 'user-managed-env',
#    'version': 'Autosave_2021-08-23T15:00:38Z_9534cc42',
#    'python': {'interpreterPath': 'python',
#     'userManagedDependencies': True,
#     'condaDependencies': {'channels': ['anaconda', 'conda-forge'],
#      'dependencies': ['python=3.6.2', {'pip': ['azureml-defaults']}],
#      'name': 'project_environment'},
#     'baseCondaEnvironment': None},
#    'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'},
#    'docker': {'baseImage': 'mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210714.v1',
#     'platform': {'os': 'Linux', 'architecture': 'amd64'},
#     'baseDockerfile': None,
#     'baseImageRegistry': {'address': None, 'username': None, 'password': None},
#     'enabled': False,
#     'arguments': []},
#    'spark': {'repositories': [], 'packages': [], 'precachePackages': True},
#    'inferencingStackVersion': None},
#   'history': {'outputCollection': True,
#    'directoriesToWatch': ['logs'],
#    'enableMLflowTracking': True,
#    'snapshotProject': True},
#   'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment',
#     'spark.yarn.maxAppAttempts': '1'}},
#   'parallelTask': {'maxRetriesPerWorker': 0,
#    'workerCountPerNode': 1,
#    'terminalExitCodes': None,
#    'configuration': {}},
#   'amlCompute': {'name': None,
#    'vmSize': None,
#    'retainCluster': False,
#    'clusterMaxNodeCount': None},
#   'aiSuperComputer': {'instanceType': 'AISupercomputer.D2',
#    'imageVersion': 'pytorch-1.7.0',
#    'location': None,
#    'aiSuperComputerStorageData': None,
#    'interactive': False,
#    'scalePolicy': None,
#    'virtualClusterArmId': None,
#    'tensorboardLogDirectory': None,
#    'sshPublicKey': None,
#    'enableAzmlInt': True,
#    'priority': 'Medium',
#    'slaTier': 'Standard',
#    'userAlias': None},
#   'kubernetesCompute': {'instanceType': None},
#   'tensorflow': {'workerCount': 1, 'parameterServerCount': 1},
#   'mpi': {'processCountPerNode': 1},
#   'pyTorch': {'communicationBackend': 'nccl', 'processCount': None},
#   'hdi': {'yarnDeployMode': 'Cluster'},
#   'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5},
#   'exposedPorts': None,
#   'docker': {'useDocker': False,
#    'sharedVolumes': True,
#    'shmSize': '2g',
#    'arguments': []},
#   'cmk8sCompute': {'configuration': {}},
#   'commandReturnCodeConfig': {'returnCode': 'Zero',
#    'successfulReturnCodes': []},
#   'environmentVariables': {},
#   'applicationEndpoints': {},
#   'parameters': [],
#   'dataBricks': {'workers': 0,
#    'minimumWorkerCount': 0,
#    'maxMumWorkerCount': 0,
#    'sparkVersion': '4.0.x-scala2.11',
#    'nodeTypeId': 'Standard_D3_v2',
#    'sparkConf': {},
#    'sparkEnvVars': {},
#    'instancePoolId': None,
#    'timeoutSeconds': 0,
#    'jarLibraries': [],
#    'eggLibraries': [],
#    'whlLibraries': [],
#    'pypiLibraries': [],
#    'rCranLibraries': [],
#    'mavenLibraries': []}},
#  'logFiles': {'azureml-logs/60_control_log.txt': 'https://mldemowsstorage8261d481a.blob.core.windows.net/azureml/ExperimentRun/dcid.cifar10_cnn_remote_1629732321_e5e480bb/azureml-logs/60_control_log.txt?sv=2019-07-07&sr=b&sig=v5m7Vk3SOE4CyjtTJlte6hh1cCEHPfyXrE7b0IxpAWI%3D&st=2021-08-23T15%3A25%3A12Z&se=2021-08-23T23%3A35%3A12Z&sp=r',
#   'azureml-logs/70_driver_log.txt': 'https://mldemowsstorage8261d481a.blob.core.windows.net/azureml/ExperimentRun/dcid.cifar10_cnn_remote_1629732321_e5e480bb/azureml-logs/70_driver_log.txt?sv=2019-07-07&sr=b&sig=30DV1b7mKWaGX6KVqKMq1kcuqMC%2FV6cHG1orcMBqeRk%3D&st=2021-08-23T15%3A25%3A12Z&se=2021-08-23T23%3A35%3A12Z&sp=r',
#   'logs/azureml/60076_azureml.log': 'https://mldemowsstorage8261d481a.blob.core.windows.net/azureml/ExperimentRun/dcid.cifar10_cnn_remote_1629732321_e5e480bb/logs/azureml/60076_azureml.log?sv=2019-07-07&sr=b&sig=Ef1yVquRA%2Fq55eqSZv%2FgLpLEYqFUlbUuAd6JWBqf6dk%3D&st=2021-08-23T15%3A15%3A42Z&se=2021-08-23T23%3A25%3A42Z&sp=r'},
#  'submittedBy': 'Marcel Alsdorf'}
