# %%
from utils import *

# %%
from azureml.core import Workspace
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication(tenant_id="c643d8c8-4abb-47ba-808c-bf73f60161f1")

# Configure workspace
ws = Workspace.from_config(auth=interactive_auth)

# %%
from azureml.core.model import InferenceConfig

env = get_env(name="sentiment-analysis", packages=["pandas", "inference-schema", "tensorflow", "transformers"])

inference_config = InferenceConfig(
    environment=env,
    source_directory="code",
    entry_script="sentiment_analysis_pandas.py",
)

# %%
from azureml.core.webservice import AciWebservice

deployment_config = AciWebservice.deploy_configuration(
    cpu_cores=0.5, memory_gb=1, auth_enabled=True
)

# %%
from azureml.core import Model

service = Model.deploy(
    ws,
    "sentiment-analysis-pandas",
    [],
    inference_config,
    deployment_config,
    overwrite=True,
)
service.wait_for_deployment(show_output=True)
# Out:
# Tips: You can try get_logs(): https://aka.ms/debugimage#dockerlog or local deployment: https://aka.ms/debugimage#debug-locally to debug if deployment takes longer than 10 minutes.
# Running
# 2022-01-02 19:31:59+00:00 Creating Container Registry if not exists.
# 2022-01-02 19:31:59+00:00 Registering the environment.
# 2022-01-02 19:31:59+00:00 Use the existing image.
# 2022-01-02 19:32:00+00:00 Submitting deployment to compute.
# 2022-01-02 19:32:03+00:00 Checking the status of deployment sentiment-analysis-pandas..
# 2022-01-02 19:34:04+00:00 Checking the status of inference endpoint sentiment-analysis-pandas.
# Succeeded
# ACI service creation operation finished, operation "Succeeded"

# %%
print(service.get_logs())
# Out:
# 2022-01-02T19:33:14,787483700+00:00 - rsyslog/run
# 2022-01-02T19:33:14,783014900+00:00 - iot-server/run
# 2022-01-02T19:33:14,808359100+00:00 - gunicorn/run
# Dynamic Python package installation is disabled.
# Starting HTTP server
# 2022-01-02T19:33:14,898141500+00:00 - nginx/run
# EdgeHubConnectionString and IOTEDGE_IOTHUBHOSTNAME are not set. Exiting...
# 2022-01-02T19:33:15,383034200+00:00 - iot-server/finish 1 0
# 2022-01-02T19:33:15,415262300+00:00 - Exit code 1 is normal. Not restarting iot-server.
# Starting gunicorn 20.1.0
# Listening at: http://127.0.0.1:31311 (58)
# Using worker: sync
# worker timeout is set to 300
# Booting worker with pid: 90
# 2022-01-02 19:33:19.130977: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /azureml-envs/azureml_8d6ea1096daefa3e7eae9e57841fbb1d/lib:/azureml-envs/azureml_8d6ea1096daefa3e7eae9e57841fbb1d/lib:
# 2022-01-02 19:33:19.131265: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# SPARK_HOME not set. Skipping PySpark Initialization.
# Initializing logger
# 2022-01-02 19:33:23,261 | root | INFO | Starting up app insights client
# logging socket was found. logging is available.
# logging socket was found. logging is available.
# 2022-01-02 19:33:23,262 | root | INFO | Starting up request id generator
# 2022-01-02 19:33:23,263 | root | INFO | Starting up app insight hooks
# 2022-01-02 19:33:23,263 | root | INFO | Invoking user's init function
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english)
# Downloading:   0%|          | 0.00/629 [00:00<?, ?B/s]
#
# Downloading:   0%|          | 0.00/629 [00:00<?, ?B/s]
# Downloading: 100%|██████████| 629/629 [00:00<00:00, 103kB/s]
#
# Downloading: 100%|██████████| 629/629 [00:00<00:00, 103kB/s]
# Downloading:   0%|          | 0.00/256M [00:00<?, ?B/s]
#
# Downloading:   0%|          | 0.00/256M [00:00<?, ?B/s]
# Downloading:   1%|          | 2.38M/256M [00:00<00:10, 24.5MB/s]
# Downloading:   1%|          | 2.38M/256M [00:00<00:10, 24.5MB/s]
#
# Downloading:   2%|▏         | 4.71M/256M [00:00<00:11, 23.6MB/s]
# Downloading:   2%|▏         | 4.71M/256M [00:00<00:11, 23.6MB/s]
#
# Downloading:   3%|▎         | 6.96M/256M [00:00<00:11, 23.0MB/s]
#
# Downloading:   3%|▎         | 6.96M/256M [00:00<00:11, 23.0MB/s]
# Downloading:   4%|▎         | 9.16M/256M [00:00<00:11, 22.0MB/s]
#
# Downloading:   4%|▎         | 9.16M/256M [00:00<00:11, 22.0MB/s]
# Downloading:   4%|▍         | 11.3M/256M [00:00<00:11, 21.6MB/s]
#
# Downloading:   4%|▍         | 11.3M/256M [00:00<00:11, 21.6MB/s]
# Downloading:   5%|▌         | 13.3M/256M [00:00<00:12, 19.6MB/s]
#
# Downloading:   5%|▌         | 13.3M/256M [00:00<00:12, 19.6MB/s]
# Downloading:   6%|▌         | 15.2M/256M [00:00<00:12, 19.6MB/s]
#
# Downloading:   6%|▌         | 15.2M/256M [00:00<00:12, 19.6MB/s]
# Downloading:   7%|▋         | 17.2M/256M [00:00<00:12, 19.9MB/s]
#
# Downloading:   7%|▋         | 17.2M/256M [00:00<00:12, 19.9MB/s]
# Downloading:   7%|▋         | 19.1M/256M [00:00<00:12, 20.0MB/s]
# Downloading:   7%|▋         | 19.1M/256M [00:00<00:12, 20.0MB/s]
#
# Downloading:   8%|▊         | 21.2M/256M [00:01<00:11, 20.6MB/s]
# Downloading:   8%|▊         | 21.2M/256M [00:01<00:11, 20.6MB/s]
#
# Downloading:   9%|▉         | 23.2M/256M [00:01<00:12, 20.1MB/s]
#
# Downloading:   9%|▉         | 23.2M/256M [00:01<00:12, 20.1MB/s]
# Downloading:  10%|▉         | 25.1M/256M [00:01<00:12, 20.1MB/s]
# Downloading:  10%|▉         | 25.1M/256M [00:01<00:12, 20.1MB/s]
#
# Downloading:  11%|█         | 27.1M/256M [00:01<00:11, 20.1MB/s]
#
# Downloading:  11%|█         | 27.1M/256M [00:01<00:11, 20.1MB/s]
# Downloading:  11%|█▏        | 29.0M/256M [00:01<00:12, 19.7MB/s]
# Downloading:  11%|█▏        | 29.0M/256M [00:01<00:12, 19.7MB/s]
#
# Downloading:  12%|█▏        | 31.1M/256M [00:01<00:11, 20.5MB/s]
# Downloading:  12%|█▏        | 31.1M/256M [00:01<00:11, 20.5MB/s]
#
# Downloading:  13%|█▎        | 33.1M/256M [00:01<00:11, 20.0MB/s]
# Downloading:  13%|█▎        | 33.1M/256M [00:01<00:11, 20.0MB/s]
#
# Downloading:  14%|█▎        | 35.0M/256M [00:01<00:11, 20.0MB/s]
# Downloading:  14%|█▎        | 35.0M/256M [00:01<00:11, 20.0MB/s]
#
# Downloading:  14%|█▍        | 36.9M/256M [00:01<00:11, 20.1MB/s]
# Downloading:  14%|█▍        | 36.9M/256M [00:01<00:11, 20.1MB/s]
#
# Downloading:  15%|█▌        | 38.8M/256M [00:01<00:11, 19.8MB/s]
#
# Downloading:  15%|█▌        | 38.8M/256M [00:01<00:11, 19.8MB/s]
# Downloading:  16%|█▌        | 40.7M/256M [00:02<00:11, 19.4MB/s]
# Downloading:  16%|█▌        | 40.7M/256M [00:02<00:11, 19.4MB/s]
#
# Downloading:  17%|█▋        | 42.6M/256M [00:02<00:11, 19.4MB/s]
# Downloading:  17%|█▋        | 42.6M/256M [00:02<00:11, 19.4MB/s]
#
# Downloading:  18%|█▊        | 44.8M/256M [00:02<00:10, 20.5MB/s]
# Downloading:  18%|█▊        | 44.8M/256M [00:02<00:10, 20.5MB/s]
#
# Downloading:  18%|█▊        | 46.8M/256M [00:02<00:10, 20.1MB/s]
#
# Downloading:  18%|█▊        | 46.8M/256M [00:02<00:10, 20.1MB/s]
# Downloading:  19%|█▉        | 48.7M/256M [00:02<00:10, 20.0MB/s]
# Downloading:  19%|█▉        | 48.7M/256M [00:02<00:10, 20.0MB/s]
#
# Downloading:  20%|█▉        | 50.8M/256M [00:02<00:10, 20.8MB/s]
#
# Downloading:  20%|█▉        | 50.8M/256M [00:02<00:10, 20.8MB/s]
# Downloading:  21%|██        | 52.8M/256M [00:02<00:11, 18.1MB/s]
# Downloading:  21%|██        | 52.8M/256M [00:02<00:11, 18.1MB/s]
#
# Downloading:  21%|██▏       | 54.8M/256M [00:02<00:11, 18.8MB/s]
#
# Downloading:  21%|██▏       | 54.8M/256M [00:02<00:11, 18.8MB/s]
# Downloading:  22%|██▏       | 56.6M/256M [00:02<00:11, 18.8MB/s]
#
# Downloading:  22%|██▏       | 56.6M/256M [00:02<00:11, 18.8MB/s]
# Downloading:  23%|██▎       | 58.7M/256M [00:03<00:10, 19.6MB/s]
#
# Downloading:  23%|██▎       | 58.7M/256M [00:03<00:10, 19.6MB/s]
# Downloading:  24%|██▎       | 60.6M/256M [00:03<00:10, 18.9MB/s]
# Downloading:  24%|██▎       | 60.6M/256M [00:03<00:10, 18.9MB/s]
#
# Downloading:  24%|██▍       | 62.4M/256M [00:03<00:10, 18.7MB/s]
#
# Downloading:  24%|██▍       | 62.4M/256M [00:03<00:10, 18.7MB/s]
# Downloading:  25%|██▌       | 64.7M/256M [00:03<00:09, 20.2MB/s]
# Downloading:  25%|██▌       | 64.7M/256M [00:03<00:09, 20.2MB/s]
#
# Downloading:  26%|██▌       | 66.6M/256M [00:03<00:09, 20.2MB/s]
# Downloading:  26%|██▌       | 66.6M/256M [00:03<00:09, 20.2MB/s]
#
# Downloading:  27%|██▋       | 68.6M/256M [00:03<00:09, 20.4MB/s]
# Downloading:  27%|██▋       | 68.6M/256M [00:03<00:09, 20.4MB/s]
#
# Downloading:  28%|██▊       | 70.6M/256M [00:03<00:09, 19.9MB/s]
#
# Downloading:  28%|██▊       | 70.6M/256M [00:03<00:09, 19.9MB/s]
# Downloading:  28%|██▊       | 72.8M/256M [00:03<00:09, 20.9MB/s]
#
# Downloading:  28%|██▊       | 72.8M/256M [00:03<00:09, 20.9MB/s]
# Downloading:  29%|██▉       | 74.8M/256M [00:03<00:09, 20.2MB/s]
#
# Downloading:  29%|██▉       | 74.8M/256M [00:03<00:09, 20.2MB/s]
# Downloading:  30%|███       | 76.8M/256M [00:04<00:09, 20.3MB/s]
#
# Downloading:  30%|███       | 76.8M/256M [00:04<00:09, 20.3MB/s]
# Downloading:  31%|███       | 78.8M/256M [00:04<00:09, 20.6MB/s]
#
# Downloading:  31%|███       | 78.8M/256M [00:04<00:09, 20.6MB/s]
# Downloading:  32%|███▏      | 80.8M/256M [00:04<00:08, 20.6MB/s]
#
# Downloading:  32%|███▏      | 80.8M/256M [00:04<00:08, 20.6MB/s]
# Downloading:  32%|███▏      | 82.8M/256M [00:04<00:08, 20.8MB/s]
# Downloading:  32%|███▏      | 82.8M/256M [00:04<00:08, 20.8MB/s]
#
# Downloading:  33%|███▎      | 84.8M/256M [00:04<00:08, 20.4MB/s]
# Downloading:  33%|███▎      | 84.8M/256M [00:04<00:08, 20.4MB/s]
#
# Downloading:  34%|███▍      | 86.8M/256M [00:04<00:08, 20.5MB/s]
# Downloading:  34%|███▍      | 86.8M/256M [00:04<00:08, 20.5MB/s]
#
# Downloading:  35%|███▍      | 88.8M/256M [00:04<00:08, 20.9MB/s]
#
# Downloading:  35%|███▍      | 88.8M/256M [00:04<00:08, 20.9MB/s]
# Downloading:  36%|███▌      | 90.8M/256M [00:04<00:08, 20.7MB/s]
# Downloading:  36%|███▌      | 90.8M/256M [00:04<00:08, 20.7MB/s]
#
# Downloading:  36%|███▋      | 92.8M/256M [00:04<00:08, 20.3MB/s]
#
# Downloading:  36%|███▋      | 92.8M/256M [00:04<00:08, 20.3MB/s]
# Downloading:  37%|███▋      | 95.0M/256M [00:04<00:07, 21.1MB/s]
#
# Downloading:  37%|███▋      | 95.0M/256M [00:04<00:07, 21.1MB/s]
# Downloading:  38%|███▊      | 97.0M/256M [00:05<00:07, 21.0MB/s]
# Downloading:  38%|███▊      | 97.0M/256M [00:05<00:07, 21.0MB/s]
#
# Downloading:  39%|███▉      | 99.1M/256M [00:05<00:07, 21.2MB/s]
#
# Downloading:  39%|███▉      | 99.1M/256M [00:05<00:07, 21.2MB/s]
# Downloading:  40%|███▉      | 101M/256M [00:05<00:07, 20.7MB/s]
#
# Downloading:  40%|███▉      | 101M/256M [00:05<00:07, 20.7MB/s]
# Downloading:  40%|████      | 103M/256M [00:05<00:08, 19.4MB/s]
# Downloading:  40%|████      | 103M/256M [00:05<00:08, 19.4MB/s]
#
# Downloading:  41%|████▏     | 106M/256M [00:05<00:07, 20.8MB/s]
#
# Downloading:  41%|████▏     | 106M/256M [00:05<00:07, 20.8MB/s]
# Downloading:  42%|████▏     | 108M/256M [00:05<00:07, 20.8MB/s]
# Downloading:  42%|████▏     | 108M/256M [00:05<00:07, 20.8MB/s]
#
# Downloading:  43%|████▎     | 110M/256M [00:05<00:07, 20.9MB/s]
# Downloading:  43%|████▎     | 110M/256M [00:05<00:07, 20.9MB/s]
#
# Downloading:  44%|████▎     | 112M/256M [00:05<00:07, 21.4MB/s]
#
# Downloading:  44%|████▎     | 112M/256M [00:05<00:07, 21.4MB/s]
# Downloading:  45%|████▍     | 114M/256M [00:05<00:07, 20.7MB/s]
#
# Downloading:  45%|████▍     | 114M/256M [00:05<00:07, 20.7MB/s]
# Downloading:  45%|████▌     | 116M/256M [00:05<00:07, 20.7MB/s]
#
# Downloading:  45%|████▌     | 116M/256M [00:05<00:07, 20.7MB/s]
# Downloading:  46%|████▌     | 118M/256M [00:06<00:07, 20.3MB/s]
#
# Downloading:  46%|████▌     | 118M/256M [00:06<00:07, 20.3MB/s]
# Downloading:  47%|████▋     | 120M/256M [00:06<00:07, 19.8MB/s]
# Downloading:  47%|████▋     | 120M/256M [00:06<00:07, 19.8MB/s]
#
# Downloading:  48%|████▊     | 122M/256M [00:06<00:06, 20.4MB/s]
#
# Downloading:  48%|████▊     | 122M/256M [00:06<00:06, 20.4MB/s]
# Downloading:  48%|████▊     | 124M/256M [00:06<00:06, 20.3MB/s]
# Downloading:  48%|████▊     | 124M/256M [00:06<00:06, 20.3MB/s]
#
# Downloading:  49%|████▉     | 126M/256M [00:06<00:06, 20.2MB/s]
# Downloading:  49%|████▉     | 126M/256M [00:06<00:06, 20.2MB/s]
#
# Downloading:  50%|█████     | 128M/256M [00:06<00:06, 21.1MB/s]
#
# Downloading:  50%|█████     | 128M/256M [00:06<00:06, 21.1MB/s]
# Downloading:  51%|█████     | 130M/256M [00:06<00:06, 21.0MB/s]
#
# Downloading:  51%|█████     | 130M/256M [00:06<00:06, 21.0MB/s]
# Downloading:  52%|█████▏    | 132M/256M [00:06<00:06, 21.5MB/s]
#
# Downloading:  52%|█████▏    | 132M/256M [00:06<00:06, 21.5MB/s]
# Downloading:  53%|█████▎    | 134M/256M [00:06<00:06, 20.8MB/s]
# Downloading:  53%|█████▎    | 134M/256M [00:06<00:06, 20.8MB/s]
#
# Downloading:  53%|█████▎    | 136M/256M [00:07<00:05, 21.1MB/s]
# Downloading:  53%|█████▎    | 136M/256M [00:07<00:05, 21.1MB/s]
#
# Downloading:  54%|█████▍    | 138M/256M [00:07<00:05, 20.8MB/s]
#
# Downloading:  54%|█████▍    | 138M/256M [00:07<00:05, 20.8MB/s]
# Downloading:  55%|█████▍    | 140M/256M [00:07<00:06, 18.4MB/s]
#
# Downloading:  55%|█████▍    | 140M/256M [00:07<00:06, 18.4MB/s]
# Downloading:  56%|█████▌    | 142M/256M [00:07<00:06, 18.7MB/s]
#
# Downloading:  56%|█████▌    | 142M/256M [00:07<00:06, 18.7MB/s]
# Downloading:  56%|█████▋    | 144M/256M [00:07<00:06, 19.0MB/s]
# Downloading:  56%|█████▋    | 144M/256M [00:07<00:06, 19.0MB/s]
#
# Downloading:  57%|█████▋    | 146M/256M [00:07<00:05, 19.2MB/s]
#
# Downloading:  57%|█████▋    | 146M/256M [00:07<00:05, 19.2MB/s]
# Downloading:  58%|█████▊    | 148M/256M [00:07<00:05, 19.7MB/s]
# Downloading:  58%|█████▊    | 148M/256M [00:07<00:05, 19.7MB/s]
#
# Downloading:  59%|█████▊    | 150M/256M [00:07<00:05, 19.8MB/s]
# Downloading:  59%|█████▊    | 150M/256M [00:07<00:05, 19.8MB/s]
#
# Downloading:  60%|█████▉    | 152M/256M [00:07<00:05, 20.3MB/s]
# Downloading:  60%|█████▉    | 152M/256M [00:07<00:05, 20.3MB/s]
#
# Downloading:  60%|██████    | 154M/256M [00:07<00:05, 19.8MB/s]
#
# Downloading:  60%|██████    | 154M/256M [00:07<00:05, 19.8MB/s]
# Downloading:  61%|██████    | 156M/256M [00:08<00:05, 20.5MB/s]
#
# Downloading:  61%|██████    | 156M/256M [00:08<00:05, 20.5MB/s]
# Downloading:  62%|██████▏   | 158M/256M [00:08<00:05, 19.9MB/s]
# Downloading:  62%|██████▏   | 158M/256M [00:08<00:05, 19.9MB/s]
#
# Downloading:  63%|██████▎   | 160M/256M [00:08<00:05, 19.5MB/s]
#
# Downloading:  63%|██████▎   | 160M/256M [00:08<00:05, 19.5MB/s]
# Downloading:  63%|██████▎   | 162M/256M [00:08<00:05, 19.5MB/s]
# Downloading:  63%|██████▎   | 162M/256M [00:08<00:05, 19.5MB/s]
#
# Downloading:  64%|██████▍   | 164M/256M [00:08<00:04, 19.6MB/s]
#
# Downloading:  64%|██████▍   | 164M/256M [00:08<00:04, 19.6MB/s]
# Downloading:  65%|██████▍   | 166M/256M [00:08<00:04, 20.3MB/s]
#
# Downloading:  65%|██████▍   | 166M/256M [00:08<00:04, 20.3MB/s]
# Downloading:  66%|██████▌   | 168M/256M [00:08<00:04, 19.6MB/s]
#
# Downloading:  66%|██████▌   | 168M/256M [00:08<00:04, 19.6MB/s]
# Downloading:  66%|██████▋   | 170M/256M [00:08<00:04, 20.0MB/s]
#
# Downloading:  66%|██████▋   | 170M/256M [00:08<00:04, 20.0MB/s]
# Downloading:  67%|██████▋   | 172M/256M [00:08<00:04, 19.8MB/s]
#
# Downloading:  67%|██████▋   | 172M/256M [00:08<00:04, 19.8MB/s]
# Downloading:  68%|██████▊   | 174M/256M [00:09<00:04, 20.1MB/s]
#
# Downloading:  68%|██████▊   | 174M/256M [00:09<00:04, 20.1MB/s]
# Downloading:  69%|██████▉   | 176M/256M [00:09<00:04, 20.5MB/s]
#
# Downloading:  69%|██████▉   | 176M/256M [00:09<00:04, 20.5MB/s]
# Downloading:  70%|██████▉   | 178M/256M [00:09<00:04, 20.3MB/s]
#
# Downloading:  70%|██████▉   | 178M/256M [00:09<00:04, 20.3MB/s]
# Downloading:  70%|███████   | 180M/256M [00:09<00:03, 20.6MB/s]
# Downloading:  70%|███████   | 180M/256M [00:09<00:03, 20.6MB/s]
#
# Downloading:  71%|███████   | 182M/256M [00:09<00:04, 18.4MB/s]
#
# Downloading:  71%|███████   | 182M/256M [00:09<00:04, 18.4MB/s]
# Downloading:  72%|███████▏  | 183M/256M [00:09<00:04, 18.6MB/s]
#
# Downloading:  72%|███████▏  | 183M/256M [00:09<00:04, 18.6MB/s]
# Downloading:  73%|███████▎  | 186M/256M [00:09<00:03, 19.7MB/s]
# Downloading:  73%|███████▎  | 186M/256M [00:09<00:03, 19.7MB/s]
#
# Downloading:  73%|███████▎  | 188M/256M [00:09<00:03, 19.7MB/s]
#
# Downloading:  73%|███████▎  | 188M/256M [00:09<00:03, 19.7MB/s]
# Downloading:  74%|███████▍  | 189M/256M [00:09<00:03, 19.8MB/s]
#
# Downloading:  74%|███████▍  | 189M/256M [00:09<00:03, 19.8MB/s]
# Downloading:  75%|███████▍  | 191M/256M [00:09<00:03, 20.1MB/s]
# Downloading:  75%|███████▍  | 191M/256M [00:09<00:03, 20.1MB/s]
#
# Downloading:  76%|███████▌  | 194M/256M [00:10<00:03, 21.0MB/s]
#
# Downloading:  76%|███████▌  | 194M/256M [00:10<00:03, 21.0MB/s]
# Downloading:  77%|███████▋  | 196M/256M [00:10<00:02, 21.0MB/s]
# Downloading:  77%|███████▋  | 196M/256M [00:10<00:02, 21.0MB/s]
#
# Downloading:  77%|███████▋  | 198M/256M [00:10<00:02, 21.0MB/s]
# Downloading:  77%|███████▋  | 198M/256M [00:10<00:02, 21.0MB/s]
#
# Downloading:  78%|███████▊  | 200M/256M [00:10<00:02, 20.5MB/s]
# Downloading:  78%|███████▊  | 200M/256M [00:10<00:02, 20.5MB/s]
#
# Downloading:  79%|███████▉  | 202M/256M [00:10<00:02, 20.2MB/s]
#
# Downloading:  79%|███████▉  | 202M/256M [00:10<00:02, 20.2MB/s]
# Downloading:  80%|███████▉  | 204M/256M [00:10<00:02, 20.2MB/s]
#
# Downloading:  80%|███████▉  | 204M/256M [00:10<00:02, 20.2MB/s]
# Downloading:  80%|████████  | 206M/256M [00:10<00:02, 19.0MB/s]
#
# Downloading:  80%|████████  | 206M/256M [00:10<00:02, 19.0MB/s]
# Downloading:  81%|████████▏ | 208M/256M [00:10<00:02, 20.9MB/s]
#
# Downloading:  81%|████████▏ | 208M/256M [00:10<00:02, 20.9MB/s]
# Downloading:  82%|████████▏ | 210M/256M [00:10<00:02, 20.7MB/s]
#
# Downloading:  82%|████████▏ | 210M/256M [00:10<00:02, 20.7MB/s]
# Downloading:  83%|████████▎ | 212M/256M [00:11<00:02, 20.7MB/s]
# Downloading:  83%|████████▎ | 212M/256M [00:11<00:02, 20.7MB/s]
#
# Downloading:  84%|████████▍ | 214M/256M [00:11<00:02, 20.9MB/s]
#
# Downloading:  84%|████████▍ | 214M/256M [00:11<00:02, 20.9MB/s]
# Downloading:  85%|████████▍ | 216M/256M [00:11<00:02, 20.7MB/s]
#
# Downloading:  85%|████████▍ | 216M/256M [00:11<00:02, 20.7MB/s]
# Downloading:  85%|████████▌ | 218M/256M [00:11<00:01, 20.5MB/s]
#
# Downloading:  85%|████████▌ | 218M/256M [00:11<00:01, 20.5MB/s]
# Downloading:  86%|████████▌ | 220M/256M [00:11<00:01, 21.2MB/s]
#
# Downloading:  86%|████████▌ | 220M/256M [00:11<00:01, 21.2MB/s]
# Downloading:  87%|████████▋ | 222M/256M [00:11<00:01, 18.7MB/s]
#
# Downloading:  87%|████████▋ | 222M/256M [00:11<00:01, 18.7MB/s]
# Downloading:  88%|████████▊ | 224M/256M [00:11<00:01, 19.2MB/s]
#
# Downloading:  88%|████████▊ | 224M/256M [00:11<00:01, 19.2MB/s]
# Downloading:  88%|████████▊ | 226M/256M [00:11<00:01, 18.7MB/s]
#
# Downloading:  88%|████████▊ | 226M/256M [00:11<00:01, 18.7MB/s]
# Downloading:  89%|████████▉ | 228M/256M [00:11<00:01, 19.1MB/s]
#
# Downloading:  89%|████████▉ | 228M/256M [00:11<00:01, 19.1MB/s]
# Downloading:  90%|█████████ | 230M/256M [00:11<00:01, 20.0MB/s]
# Downloading:  90%|█████████ | 230M/256M [00:11<00:01, 20.0MB/s]
#
# Downloading:  91%|█████████ | 232M/256M [00:12<00:01, 20.2MB/s]
#
# Downloading:  91%|█████████ | 232M/256M [00:12<00:01, 20.2MB/s]
# Downloading:  92%|█████████▏| 234M/256M [00:12<00:01, 19.3MB/s]
# Downloading:  92%|█████████▏| 234M/256M [00:12<00:01, 19.3MB/s]
#
# Downloading:  92%|█████████▏| 236M/256M [00:12<00:01, 20.1MB/s]
#
# Downloading:  92%|█████████▏| 236M/256M [00:12<00:01, 20.1MB/s]
# Downloading:  93%|█████████▎| 238M/256M [00:12<00:00, 20.0MB/s]
# Downloading:  93%|█████████▎| 238M/256M [00:12<00:00, 20.0MB/s]
#
# Downloading:  94%|█████████▍| 240M/256M [00:12<00:00, 19.8MB/s]
# Downloading:  94%|█████████▍| 240M/256M [00:12<00:00, 19.8MB/s]
#
# Downloading:  95%|█████████▍| 242M/256M [00:12<00:00, 19.7MB/s]
#
# Downloading:  95%|█████████▍| 242M/256M [00:12<00:00, 19.7MB/s]
# Downloading:  96%|█████████▌| 244M/256M [00:12<00:00, 20.5MB/s]
#
# Downloading:  96%|█████████▌| 244M/256M [00:12<00:00, 20.5MB/s]
# Downloading:  96%|█████████▋| 246M/256M [00:12<00:00, 20.0MB/s]
#
# Downloading:  96%|█████████▋| 246M/256M [00:12<00:00, 20.0MB/s]
# Downloading:  97%|█████████▋| 248M/256M [00:12<00:00, 19.5MB/s]
#
# Downloading:  97%|█████████▋| 248M/256M [00:12<00:00, 19.5MB/s]
# Downloading:  98%|█████████▊| 250M/256M [00:13<00:00, 19.8MB/s]
#
# Downloading:  98%|█████████▊| 250M/256M [00:13<00:00, 19.8MB/s]
# Downloading:  99%|█████████▊| 252M/256M [00:13<00:00, 20.4MB/s]
#
# Downloading:  99%|█████████▊| 252M/256M [00:13<00:00, 20.4MB/s]
# Downloading:  99%|█████████▉| 254M/256M [00:13<00:00, 20.0MB/s]
#
# Downloading:  99%|█████████▉| 254M/256M [00:13<00:00, 20.0MB/s]
# Downloading: 100%|██████████| 256M/256M [00:13<00:00, 20.1MB/s]
#
# Downloading: 100%|██████████| 256M/256M [00:13<00:00, 20.1MB/s]
# 2022-01-02 19:33:39.274506: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /azureml-envs/azureml_8d6ea1096daefa3e7eae9e57841fbb1d/lib:/azureml-envs/azureml_8d6ea1096daefa3e7eae9e57841fbb1d/lib:
# 2022-01-02 19:33:39.274805: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-01-02 19:33:39.275342: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (SandboxHost-637767487262938675): /proc/driver/nvidia/version does not exist
# 2022-01-02 19:33:39.276403: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-01-02 19:33:39.374488: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# 2022-01-02 19:33:39.548958: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 93763584 exceeds 10% of free system memory.
# 2022-01-02 19:33:41.274323: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 93763584 exceeds 10% of free system memory.
# 2022-01-02 19:33:41.425812: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 93763584 exceeds 10% of free system memory.
# 2022-01-02 19:33:46.790352: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 93763584 exceeds 10% of free system memory.
# 2022-01-02 19:33:46.967742: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 93763584 exceeds 10% of free system memory.
# All model checkpoint layers were used when initializing TFDistilBertForSequenceClassification.
#
# All the layers of TFDistilBertForSequenceClassification were initialized from the model checkpoint at distilbert-base-uncased-finetuned-sst-2-english.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFDistilBertForSequenceClassification for predictions without further training.
# Downloading:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
#
# Downloading:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Downloading: 100%|██████████| 48.0/48.0 [00:00<00:00, 12.8kB/s]
#
# Downloading: 100%|██████████| 48.0/48.0 [00:00<00:00, 12.8kB/s]
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
#
# Downloading:   2%|▏         | 4.00k/226k [00:00<00:23, 9.48kB/s]
#
# Downloading:   2%|▏         | 4.00k/226k [00:00<00:23, 9.48kB/s]
# Downloading:   7%|▋         | 16.0k/226k [00:00<00:06, 34.8kB/s]
# Downloading:   7%|▋         | 16.0k/226k [00:00<00:06, 34.8kB/s]
#
# Downloading:  19%|█▉        | 44.0k/226k [00:00<00:02, 89.6kB/s]
#
# Downloading:  19%|█▉        | 44.0k/226k [00:00<00:02, 89.6kB/s]
# Downloading:  29%|██▉       | 66.0k/226k [00:00<00:01, 113kB/s]
# Downloading:  29%|██▉       | 66.0k/226k [00:00<00:01, 113kB/s]
#
# Downloading:  36%|███▋      | 82.0k/226k [00:00<00:01, 116kB/s]
#
# Downloading:  36%|███▋      | 82.0k/226k [00:00<00:01, 116kB/s]
# Downloading:  47%|████▋     | 106k/226k [00:01<00:00, 136kB/s]
# Downloading:  47%|████▋     | 106k/226k [00:01<00:00, 136kB/s]
#
# Downloading:  61%|██████    | 138k/226k [00:01<00:00, 169kB/s]
#
# Downloading:  61%|██████    | 138k/226k [00:01<00:00, 169kB/s]
# Downloading:  75%|███████▌  | 170k/226k [00:01<00:00, 192kB/s]
#
# Downloading:  75%|███████▌  | 170k/226k [00:01<00:00, 192kB/s]
# Downloading:  96%|█████████▋| 218k/226k [00:01<00:00, 244kB/s]
# Downloading:  96%|█████████▋| 218k/226k [00:01<00:00, 244kB/s]
#
# Downloading: 100%|██████████| 226k/226k [00:01<00:00, 153kB/s]
#
# Downloading: 100%|██████████| 226k/226k [00:01<00:00, 153kB/s]
# 2022-01-02 19:34:01,159 | root | INFO | Users's init has completed successfully
# 2022-01-02 19:34:01,164 | root | INFO | Skipping middleware: dbg_model_info as it's not enabled.
# 2022-01-02 19:34:01,165 | root | INFO | Skipping middleware: dbg_resource_usage as it's not enabled.
# Generating swagger file: /tmp/tmplfy832sb
# 2022-01-02 19:34:01,169 | root | INFO | Scoring timeout is found from os.environ: 60000 ms
# 2022-01-02 19:34:04,648 | root | INFO | 200
# 127.0.0.1 - - [02/Jan/2022:19:34:04 +0000] "GET /swagger.json HTTP/1.0" 200 2445 "-" "Go-http-client/1.1"
# 2022-01-02 19:34:07,175 | root | INFO | 200
# 127.0.0.1 - - [02/Jan/2022:19:34:07 +0000] "GET /swagger.json HTTP/1.0" 200 2445 "-" "Go-http-client/1.1"

# %%
import requests
import json
from azureml.core import Webservice

service = Webservice(workspace=ws, name="sentiment-analysis-pandas")
scoring_uri = service.scoring_uri

# If the service is authenticated, set the key or token
key, _ = service.get_keys()

# Set the appropriate headers
headers = {"Content-Type": "application/json"}
headers["Authorization"] = f"Bearer {key}"

data = {
    "Inputs": {
        "data": [
            {"query": "My ML skills are quite good."},   
            {"query": "I didn't have good experience with ML."}
        ]
    }
}
data = json.dumps(data)
resp = requests.post(scoring_uri, data=data, headers=headers)
print(resp.text)
# Out:
# [{"sentiment_label": "POSITIVE", "sentiment_score": 0.9998338223}, {"sentiment_label": "NEGATIVE", "sentiment_score": 0.9997455478}]

# %%
scoring_uri
# Out:
# 'http://15bb1af2-25cb-4e74-9872-a0e19283c649.westus2.azurecontainer.io/score'

# %%
# service.delete()
